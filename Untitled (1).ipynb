# %% [markdown]
# Data Science Projects on Area and Population

# %%
import pandas as pd
cities = pd.read_csv("california_cities.csv")
cities
# Out:
#      Unnamed: 0         city       latd       longd  elevation_m  \
# 0             0     Adelanto  34.576111 -117.432778        875.0
# 1             1  AgouraHills  34.153333 -118.761667        281.0
# 2             2      Alameda  37.756111 -122.274444          NaN
# 3             3       Albany  37.886944 -122.297778          NaN
# 4             4     Alhambra  34.081944 -118.135000        150.0
# ..          ...          ...        ...         ...          ...
# 477         477   Yountville  38.403056 -122.362222         30.0
# 478         478        Yreka  41.726667 -122.637500        787.0
# 479         479     YubaCity  39.134722 -121.626111         18.0
# 480         480      Yucaipa  34.030278 -117.048611        798.0
# 481         481  YuccaValley  34.133333 -116.416667       1027.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0          2871.0             31765            56.027           56.009
# ...

# %%
#extracting data that is needed
latitude, longitude = cities['latd'], cities['longd']
population, area = cities['population_total'], ['area_total_km2']

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn
seaborn.set()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn
seaborn.set()
plt.scatter(longitude, latitude, label=None, c=np.log10(population),
            cmap='viridis', s=area, linewidth=0, alpha=0.5)
plt.axis(aspect='equal')
plt.xlabel('Longitude')
plt.ylabel('Longitude')
plt.colorbar(label='log$_{10}$(population)')
plt.clim(3, 7)
# Create an empty list to hold the dummy scatter plots
dummy_plots = []

# Iterate over the area sizes
for area in [100, 300, 500]:
    # Create a dummy scatter plot with no data points, only for the legend
    dummy_plot = plt.scatter([], [], c='k', alpha=0.3, s=area, label=str(area) + " km²")
    dummy_plots.append(dummy_plot)

# Show the legend with the dummy plots
plt.legend(handles=dummy_plots, scatterpoints=1, frameon=False, labelspacing=1, title='City Areas')

# Set the title of the plot
plt.title("Area and population of California cities")

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 7
#       4 seaborn.set()
#       5 plt.scatter(longitude, latitude, label=None, c=np.log10(population),
#       6             cmap='viridis', s=area, linewidth=0, alpha=0.5)
# ----> 7 plt.axis(aspect='equal')
#       8 plt.xlabel('Longitude')
#       9 plt.ylabel('Longitude')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2701, in axis(arg, emit, **kwargs)
#    2693 @_copy_docstring_and_deprecators(Axes.axis)
#    2694 def axis(
#    2695     arg: tuple[float, float, float, float] | bool | str | None = None,
#    (...)
#    2699     **kwargs,
#    2700 ) -> tuple[float, float, float, float]:
# -> 2701     return gca().axis(arg, emit=emit, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:2133, in _AxesBase.axis(self, arg, emit, **kwargs)
# ...
